# %%
import numpy as np
import matplotlib.pyplot as plt

data = [
    [1, 1, 1],
    [3, 1, 0],
    [1, 3, 0],
    [3, 3, 0]
]

def rect (b, a, x):
    return b*x + a

t = np.arange(-10, 10, 1)


plt.plot(t, rect(-3, 3, t))

plt.plot(t, rect(3, 3, t))
